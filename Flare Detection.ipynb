# %%
# !nvidia-smi
# Out:
# Thu Feb  1 15:02:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 80.2MB/s]
# Ultralytics YOLOv8.1.10 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 92.7MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 103.4ms
# Speed: 12.6ms preprocess, 103.4ms inference, 977.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/fire
# Out:
# /content/drive/.shortcut-targets-by-id/12jT5ZfKpVYmetZsY3Dvr9Ep-k4ltJJop/fire

# %%
# !ls
# Out:
# data.yaml  test  train	valid

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=416 plots=True
# Out:
# ...
# ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt...
# ...
#                                                                                                 0.0%curl: (23) Failure writing output to destination
#
# ⚠️ Download failure, retrying 2/3 https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt...
# ...
#                                                                                                 0.0%curl: (23) Failure writing output to destination
#
# ⚠️ Download failure, retrying 3/3 https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt...
# ...
# curl: (23) Failure writing output to destination
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/utils/downloads.py", line 324, in safe_download
#     assert r == 0, f"Curl return value {r}"
# AssertionError: Curl return value 23
#
# ...

# %%
# !ls /content/drive/MyDrive/D-Fire/runs/detect/train
# Out:
# args.yaml					     train_batch1652.jpg
# confusion_matrix_normalized.png			     train_batch1.jpg
# confusion_matrix.png				     train_batch2.jpg
# events.out.tfevents.1690524149.551518c91b9e.14175.0  val_batch0_labels.jpg
# labels_correlogram.jpg				     val_batch0_pred.jpg
# labels.jpg					     val_batch1_labels.jpg
# results.csv					     val_batch1_pred.jpg
# results.png					     val_batch2_labels.jpg
# train_batch0.jpg				     val_batch2_pred.jpg
# train_batch1650.jpg				     weights
# train_batch1651.jpg

# %%
from IPython.display import display, Image

# %%
Image(filename='/content/drive/MyDrive/D-Fire/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/D-Fire/runs/detect/train/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch0_labels.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch1_labels.jpg', width=600)

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/D-Fire/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch0_labels.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/runs/detect/train/val_batch0_labels.jpg: 224x416 104 smokes, 204.3ms
# Speed: 1.6ms preprocess, 204.3ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 416)
# Results saved to runs/detect/predict11

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch0_pred.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/runs/detect/train/val_batch0_pred.jpg: 320x640 1 person, 1 stop sign, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict3

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch1_labels.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/runs/detect/train/val_batch1_labels.jpg: 320x640 4 cars, 105.4ms
# Speed: 3.0ms preprocess, 105.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict4

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch1_pred.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/runs/detect/train/val_batch1_pred.jpg: 320x640 5 cars, 156.7ms
# Speed: 7.5ms preprocess, 156.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict5

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch2_labels.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/runs/detect/train/val_batch2_labels.jpg: 320x640 3 buss, 189.7ms
# Speed: 2.7ms preprocess, 189.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict6

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/runs/detect/train/val_batch2_pred.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/runs/detect/train/val_batch2_pred.jpg: 320x640 1 train, 1 truck, 57.8ms
# Speed: 1.9ms preprocess, 57.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict7

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/valid/images/AoF06723.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06723.jpg: 384x640 1 car, 60.8ms
# Speed: 1.8ms preprocess, 60.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict10

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/drive/MyDrive/D-Fire/valid/images/AoF06724.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06724.jpg: 352x640 (no detections), 103.2ms
# Speed: 3.0ms preprocess, 103.2ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict20

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/D-Fire/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/D-Fire/valid/images/AoF06725.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06725.jpg: 256x416 (no detections), 98.1ms
# Speed: 1.6ms preprocess, 98.1ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict22

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/D-Fire/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/D-Fire/valid/images/AoF06723.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06723.jpg: 256x416 (no detections), 96.9ms
# Speed: 1.7ms preprocess, 96.9ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict23

# %%
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06724.jpg: 224x416 (no detections), 95.0ms
# Speed: 1.5ms preprocess, 95.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 416)
# Results saved to runs/detect/predict24

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/D-Fire/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/D-Fire/valid/images/AoF06725.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06725.jpg: 256x416 (no detections), 98.4ms
# Speed: 1.6ms preprocess, 98.4ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict25

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/D-Fire/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/D-Fire/valid/images/AoF06726.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/valid/images/AoF06726.jpg: 256x416 (no detections), 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict26

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/D-Fire/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/D-Fire/train/images/AoF00000.jpg"
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/D-Fire/train/images/AoF00000.jpg: 256x416 (no detections), 122.6ms
# Speed: 1.6ms preprocess, 122.6ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict27
