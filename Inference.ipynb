# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('/content/drive/MyDrive/smoke detection weight.pt')

results = model.predict(r'/content/drive/MyDrive/vid2.webm', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/356) /content/drive/MyDrive/vid2.webm: 480x800 (no detections), 531.4ms
# video 1/1 (2/356) /content/drive/MyDrive/vid2.webm: 480x800 (no detections), 391.2ms
# video 1/1 (3/356) /content/drive/MyDrive/vid2.webm: 480x800 (no detections), 386.1ms
# video 1/1 (4/356) /content/drive/MyDrive/vid2.webm: 480x800 (no detections), 368.1ms
# video 1/1 (5/356) /content/drive/MyDrive/vid2.webm: 480x800 (no detections), 379.0ms
# ...

# %%
# Video 1 took 658.7ms on CPU vs 8.4ms on GPU T4
# Video 2 took 8.3ms on GPU T4
# Video 3 took 9.8ms on GPU T4
